# %% [markdown]
# # Libraries

# %%
from social_text_processing import *
from datetime import datetime
import pickle
import numpy as np
import emoji
from oauth2client.service_account import ServiceAccountCredentials
import gspread
import pandas as pd
import re
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Activation, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from nltk.stem.snowball import SnowballStemmer
import warnings
warnings.filterwarnings('ignore')
import joblib
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
import os
from tensorflow.keras.utils import to_categorical
from sklearn.linear_model import LogisticRegression
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import SGDClassifier
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
import warnings
warnings.filterwarnings('ignore')

# %%
RUNTIME = str(datetime.today())
RUNTIME = RUNTIME.replace('-', '').replace(' ', '').replace(':', '')[0:-13]

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # Read In Data

# %% [markdown]
# ## Functions to Read Data

# %%
SCOPES = ['https://spreadsheets.google.com/feeds',
          'https://www.googleapis.com/auth/drive']
LABELED_POSTS_SHEET = '1Dd5Ug-PeAOSrPm4zUUhBTvZkjgm14HWZwY_h8oj79Xg'
CREDENTIALS = 'google-credentials.json'
creds = ServiceAccountCredentials.from_json_keyfile_name(CREDENTIALS, SCOPES)
client = gspread.authorize(creds)

# %%
def read_sheets(sheet_id):
    df = pd.DataFrame()
    spreadsheet = client.open_by_key(sheet_id)
    
    for i in range(len(spreadsheet.worksheets())):
        this_df = pd.DataFrame(spreadsheet.get_worksheet(i).get_all_records())
        df = df.append(this_df)
    
    df = df[['text', 'label']]
    df.dropna(inplace=True)
    df = df[df['label'] != '']
    df = df[df['text'] != '']
    
    return df

# %%
df = read_sheets(LABELED_POSTS_SHEET)
# df_train.dropna(inplace=True)

# %%
df['label'].value_counts()
# Out:
#  0    3209
#  1     824
# -1     315
# Name: label, dtype: int64

# %% [markdown]
# # Resample

# %%
positives = df[df['label'] == 1]
negatives = df[df['label'] == -1]
neutral = df[df['label'] == 0]
sampled_neutral = neutral.sample(frac=1)[0:1000]

# %%
combined = positives.append(negatives).append(sampled_neutral).sample(frac=1)

# %%
combined.shape[0]
# Out:
# 2139

# %% [markdown]
# ## Create Train / Test Sets

# %%
VOCAB_SIZE = 3000
TRAIN_PORTION = .5

# %%
X = df['text']
y = df['label'].tolist()
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=11, 
                                                    shuffle=True, train_size=TRAIN_PORTION)

# %%
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
y_train_fitted = label_encoder.transform(y_train)
y_test_fitted = label_encoder.transform(y_test)

# %% [markdown]
# # Emojis

# %%
nlp = spacy.load('en')
emoji = Emoji(nlp)
nlp.add_pipe(emoji, first=True)

# %% [markdown]
# # Pipeline

# %% [markdown]
# ## Preprocessing Pipeline for Tokenizer

# %%
preprocessing_pipeline = Pipeline(
    steps=[
        ('remove_punctuation', RemovePunctuation()),
        ('remove_urls', RemoveURLs()),
        ('remove_usernames', RemoveUsernames()),
        ('remove_stopwords', RemoveStopwords()),
        ('convert_emojis', ConvertEmojis()),
#         ('change_common_words', CommonWordAdjustments()),
        ('remove_numbers', RemoveNumbers()),
        ('stem', Stem()),
        ('lemmatize', Lemmatize()),
        ('export', Export()),
        ('drop_unneeded_features', FeatureSelector('cleaned_title')),
    ]
)

# %% [markdown]
# ## Full Pipeline

# %%
full_pipeline = Pipeline(
    steps=[
        ('remove_punctuation', RemovePunctuation()),
        ('remove_urls', RemoveURLs()),
        ('remove_usernames', RemoveUsernames()),
        ('remove_stopwords', RemoveStopwords()),
        ('convert_emojis', ConvertEmojis()),
#         ('change_common_words', CommonWordAdjustments()),
        ('remove_numbers', RemoveNumbers()),
        ('stem', Stem()),
        ('lemmatize', Lemmatize()),
        ('tokenize', TokenizeText()),
        ('model', XGBClassifier(n_estimators=500))
    ]
)

# %% [markdown]
# ## Preprocess Text

# %%
preprocessing_pipeline.fit(X_train, y_train)
# Out:
# [["rt user big mileston day solana devnet parti popper parti popper parti popper number peopl experienc soda lend ' ve receiv"], ['fetch team continu amaz user want cross chain swap good protocol actual secur user dust url'], ['polic car light polic car light polic car light polic car light polic car light polic car light polic car light polic car light polic car light polic car light number eth number , number usd transfer unknown wallet unknown wallet url'], ['solana url'], ['rt user look passiv incom end search user blue circl tg http']]
# Pipeline(steps=[('remove_punctuation', RemovePunctuation()),
#                 ('remove_urls', RemoveURLs()),
#                 ('remove_usernames', RemoveUsernames()),
#                 ('remove_stopwords', RemoveStopwords()),
#                 ('convert_emojis', ConvertEmojis()),
#                 ('remove_numbers', RemoveNumbers()), ('stem', Stem()),
#                 ('lemmatize', Lemmatize()), ('export', Export()),
#                 ('drop_unneeded_features',
#                  FeatureSelector(feature_names='cleaned_title'))])

# %% [markdown]
# ## Tokenize Text

# %%
processed_text = pd.read_csv('processed_text.csv')
text = processed_text['text']
vectorizer = CountVectorizer(ngram_range=(1,1))
vectorizer.fit(text)

with open(f'tokenizer.pickle', 'wb') as handle:
    pickle.dump(vectorizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Full Pipeline

# %%
param_grid = {
    'model__n_estimators': [25, 100, 500, 1000],
    'model__learning_rate': [.1, .3, .7]
}

# %%
full_pipeline.fit(X_train, list(y_train))
# grid = GridSearchCV(full_pipeline, param_grid, n_jobs=-1, scoring='roc_auc')
# grid.fit(X_train, list(y_train))
# Out:
# [22:21:49] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Pipeline(steps=[('remove_punctuation', RemovePunctuation()),
#                 ('remove_urls', RemoveURLs()),
#                 ('remove_usernames', RemoveUsernames()),
#                 ('remove_stopwords', RemoveStopwords()),
#                 ('convert_emojis', ConvertEmojis()),
#                 ('remove_numbers', RemoveNumbers()), ('stem', Stem()),
#                 ('lemmatize', Lemmatize()), ('tokenize', TokenizeText()),
#                 ('model',
#                  XGBClassifier(base_score=0.5, booste...
#                                importance_type='gain',
#                                interaction_constraints='',
#                                learning_rate=0.300000012, max_delta_step=0,
#                                max_depth=6, min_child_weight=1, missing=nan,
#                                monotone_constraints='()', n_estimators=500,
#                                n_jobs=16, num_parallel_tree=1,
#                                objective='multi:softprob', random_state=0,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=None,
#                                subsample=1, tree_method='exact',
#                                validate_parameters=1, verbosity=None))])

# %% [markdown]
# # Predict - Evaluation Set

# %%
label_maps = {0: -1, 1: 0, 2: 1}
eval_preds = label_encoder.transform(full_pipeline.predict(X_train))

# %%
print (classification_report(eval_preds, y_train_fitted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       153
#            1       1.00      0.99      0.99      1586
#            2       0.97      0.98      0.98       435
#
#     accuracy                           0.99      2174
#    macro avg       0.98      0.99      0.98      2174
# weighted avg       0.99      0.99      0.99      2174

# %% [markdown]
# # Export Model

# %%
joblib.dump(full_pipeline, f'social_bow_model_{RUNTIME}.joblib')
# Out:
# ['social_bow_model_20210929.joblib']

# %% [markdown]
# # Test Set

# %%
loaded_model = joblib.load(f'social_bow_model_{RUNTIME}.joblib')

# %%
label_maps = {2: "Positive", 1: "Neutral", 0: "Negative"}
def predict_text(text):
    prediction = label_encoder.transform(loaded_model.predict([text]))
    
    return label_maps[prediction[0]]

# %%
test_preds = loaded_model.predict(X_test)

# %%
print(classification_report(y_test, test_preds))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.48      0.29      0.36       155
#            0       0.85      0.89      0.87      1634
#            1       0.56      0.52      0.54       385
#
#     accuracy                           0.78      2174
#    macro avg       0.63      0.57      0.59      2174
# weighted avg       0.77      0.78      0.78      2174

# %%
df = pd.DataFrame(data = {
    'text': X_test,
    'actual': y_test,
    'predicted': test_preds
})

# %%
df[df['actual'] != df['predicted']]
# Out:
#                                                                                                                                                                                                                                                                                                                                                    text  \
# 722                                                                                                                                                                                                RT @CryptoAlexand: Now you must wait 😅\n But if you staking your $FET you can get $MOBIX #stakedrop. Distribution in - October - December\n \n\n @F…
# 81                                                                                                                                                                                                                                                                RT @bpascowitch: Bullish signs everywhere! \n\n#bitcoin\n#ethereum\n#cardano\n#solana
# 65                                                                                                                                                                                                                          RT @CardanoHypes: I will giveaway 500 $ADA if #Cardano reaches $3 in 24 hours! 😱🚀\n\nMUST:\n&gt; RT + LIKE \n&gt; Follow me
# 355                                                                                                                                                                                                        RT @MOONSHOTJOSH: @papousse47 @Fetch_ai Mark your calendar for $FET deep parking demos. #Jaguar #Bmw #Tesla in early September. https://t.c…
# 261                                                                                                                                                                                                        RT @daimetti: @Fetch_ai #Ai #CollectiveLearning #nft  Made my votes for the AI driven NFT collection. Some awesome stuff on here. @HMsheikh…
# 44                                                             “Without a strong and scalable social layer, crypto-networks/ecosystems tend to fall apart and/or get bogged down by constant infighting over trivial topics. Within Ethereum, there is currently a bit of elitism around layer 2’s (rollups) vs sidechains which has led to some drama”
# 400                                                                                     @AkashTrade @Mettalex I have been averaging in on $MTLX for a few months now. Only token that has gotten My Fiat in over a year. Love the project, and @Fetch_ai team. Learned of them when I got about 20 free $MTLX through the $FET Phoenix staking program.
# 167                                                                                                                                                                                                               @cardano_bull @garyvee You think he got handed that 100 mills to him haha, he worked for them and believed in himself, do the same ;)
# 80                                                                                                                                                                                                   RT @CryptoWizardd: STILL AWAKE\n\n6th time last tweet\n\nDont miss $Fet\n\nZoom out. Relax and enjoy the ride\n\n@Fetch_ai https://t.co/UCJfxF8Bmf
# 220                                                                                                                                                                                                                                                                                @Solana_Alpha If you managed to get even 1 you are quite special lol
# 378                                                                                                                                                                                                                                                    @geoff_l @Narodism Solana gaming is going to be the killer feature. Nfts linked to defi markets.
# 433                                                                                                                                                                                            RT @cryptorecruitr: Small fish and big whales, they are all accumulating #Bitcoin \n \n\n Here is how that correlates to the charts!\n \n\n https://t.c…
# 709                                                                                                                                                                                                  RT @Eric_BobbyRay: @Fetch_ai / $FET is a great project with so much to offer to the Crypto community\n \n\n Found this gem💎 on https://t.co/jEAXi…
# 197                                                                                                                                                                                                                             $SHIB #SHIBASWAP $SHIBA #SHIBARMY #shibainu $LEASH #shibtothemoon\n💥👉https://t.co/vHBr9TBhx1 👈💥 https://t.co/XzD4Yv0ITg
# 475                                                                                                                                                                                                                                                            @TuffGuysNFT I'M TUFF ENOUGH!!\nLet's go!\n\n#NFT #NFTCommunity #NFTcollection #Ethereum
# 701                                                                                                                                                                                                                            RT @rovercrc: Time is ticking ⏰\n \n\n #Bitcoin is still on sale. But it won’t take long before the FOMO kicks in again.
# 485                                                                                                         Gas used in currently pending transactions:\n\n🚀 15 seconds &gt;&gt;&gt;&gt; 90 Gwei\n🚗 1 minute  &gt;&gt;&gt;&gt;&gt; 80 Gwei\n🐌 3 minutes &gt;&gt;&gt;&gt;&gt; 79 Gwei\n🦥 &gt;10 minutes &gt;&gt;&gt; 79 Gwei\n\n#Ethereum #ETH #GasPrice
# 143                                                                                                         @elonmusk With all due respect Sir,\nToo many puzzles Elon,\nIt's time for tesla to finally start accepting Dogecoin.\nPeople like me are already losing faith in Doge and selling in loss..\nI don't see that situation under control Sir.
# 119                                                                                                                                                 @Fetch_ai @coinbase I enjoy investing in AI technology company @Fetch_ai except the extortionate gas fees.\nHolding a bag (long-term) and curse ETH when I look to top up.\nPlease find a solution.
# 216                                                                                                                                                                                                                                                                        soon some news from kraken about @Fetch_ai $fet lets hope for the good news.
# 72                                                                                                                                                                                                                               RT @shibainuart: Shiba Inu $SHIB Token Is Up 25% so far Following Coinbase Listing\n\nSource:\nhttps://t.co/wZaXL62FtE
# 397                                                                                                                                                          For those that think that many technological leaps are generally impossible to achieve, I'm afraid to say that you're only obstructing those making things happen. #FetchAI $FET @Fetch_ai
# 140                                                                                                                                                                                                                                                                                                                               Shiba to da moon baby
# 323                                                                                                                                                                                                                                                                       @asaneboudayo @Shibtoken im totally agree with him \n\nshiba should burn burn
# 53                                                                                                                                                                                                                                                               RT @DoggieStyleee: Much Noise Much Wow #Dogecoin #OaklandA 🚀🚀🌕 https://t.co/27IeVVhPOw
# 258                                                                                                                                                                                                                                              @ThaMacroMan @Cardano_Robin I agree No one I know in my city are into crypto  and nfts let alone CNFTs
# 389                                                                                                                                                                                                       RT @derekking777: My fellow Portuguese brother from Brazil called the right one. The stats are kind of hard to ignore.\nDogecoin Millionaire…
# 534                                                                                                                                                                                                                                                                             Dear @Fetch_ai $fet please kindly confirm if you are burning $fet coins
# 383                                                                                                                                                                                                                                                                                                         @MOONSHOTJOSH @Fetch_ai Undervalued as hell
# 751                                                                                                                                                                                                                                   I'm trading in @Fetch_ai \n And gaing a great profit from $FET \n #crypto #fetch #altcoin https://t.co/wYOdETt5oc
# 5                                                                                                                                                                                                                                                                          Shiba Inu Token Is Up 25% Following Coinbase Listing https://t.co/dhHJHakhfn
# 695                                                                                                                                                                                                                                          RT @rovercrc: Don’t fall for the whale games. Old FUD, whales are trying to steal your #Bitcoin be WARNED!
# 255                                                                                                                                                                                                     STILL TIME, TAG 3 FRIENDS LETS GET THE BABYZ ON THE MAP🚀\n\n#SolanaSummer #SolanaNFT #NFTs #Solana #SOL #Cryptocurrency https://t.co/zjv5qGbmnG
# 101                                                                                                 WHEN EVER IN DOUBT ZOOOOOOOOOM\nIT !!!\n\n#FETARMY\n@Fetch_ai \n                ....X coins\n#ArtificialIntelligence \n#bosch\n#bmw\n#MachineLearning \n#Altcoins \n#ALTSEASON \n#dyor\n#bots\n#NFTMarketplace \n#NFTLAUNCH https://t.co/fBVO7FoZaI
# 401                                                                                                                                                                                                                            @CryptoMichNL Transactioooooooon received - 870,000,000 SHIBA INU. Thank you @SHIBAINUBONUS We are with you SHIBA INU 🤘🥰
# 149                                 @digitalassetbuy @JohnEDeaton1 The Hinman speech came out of GG’s lectures at MIT. If you look at the class where he discusses Ripple or as he calls it “XRPeeeeeyyyyy” @BlackberryXRP 🤣\nYou’ll see the similarities and opinions expressed are the same. So yes, “When Howey met Gary” is just Hegelian dialectic
# 309  $FET is the #FUTURE\n\n$FET @Fetch_AI @Jonathan6620\n$TSLA @Tesla @ElonMusk\n#Fetch #FetchAgents #DefiAgents #FetARMY #FetchAI\n#AutonomousEconomicAgent #Autonomous\n#AI #ArtificialIntelligence \n#ML #MachineLearning\n#DeFi #IOT #Blockchain #Crypto\n\n@WR4NYGov @EmmetPeppers @WholeMarsBlog https://t.co/YjZUkSgYXu https://t.co/dDIkEbZAhE
# 302                                                                                                                                                                                                                                                 RT @tokenstate: Every major DeFi app launching on Arbitrum soon. \n\nEthereum is going to the moon.
# 711                                                                                                                                                                                                                                                             RT @DylanLeClair_: oh no a communist government banned #bitcoin https://t.co/lWw8vOeIVU
# 183                                                                                                                                                                                                                                                                        RT @ShibaFuture: Trust in Shiba Inu #ShibaArmy #HODL https://t.co/qdgCEEEynT
# 98                                                                                                                                                                                                                                                                           RT @DogeMoon11: @McDonalds Now Accepting #Dogecoin https://t.co/cSTYo7DFIv
# 130                                                                                                                                                                                                    RT @SEOMalkamDior: Shiba is now on Coinbase 🏅💯❤️\n-\nhttps://t.co/wWYeR8UN5r \n\n#Algorithms #100DaysOfCode #NYC #CodeNewbies #DEVCommunity #Da…
# 377                                                                                                                                                                                                                                   Altcoin Roundup: High Ethereum fees kick-start a liquidity migration to layer-1 platforms https://t.co/UzitadwyMG
# 500                                                                                                                                                                                                     Bitcoin Nose Dives as Economic Deflation and Fiat Price Inflation grips the global economy – September 21, 2021 \n \n\n https://t.co/fxJxBrsp0J
# 58                                                                                                                                                                                                         RT @NWOmustdie: @digitalassetbuy @Ripple I think we could be seeing damage control here - make it look like a silly regulatory turf war ins…
# 521                                                                Loot, an NFT-based social network by the co-creator of Vine lets people create NFTs based on their item generator for free minus the transaction fees required by the Ethereum network with intention that the items will be part of a game or the metaverse https://t.co/JmMn3UOIeB
# 74                                                                                                                                                                                                                                                                          RT @avzettler: Just bought a bag of $AGIX @singularity_net #cardano #crypto
# 473                                                                                                                                                                                                                                                    @dvuhbkh @cito_nieves @coinbase @Fetch_ai #pump #tothemoon #LFG @coinbase @Fetch_ai #fetchaiarmy
# 34                                                                                                                                                                                                                                                                  RT @TheDogeSon1: $ETH.X $DOGE.X #Ethereum #Dogecoin Batman and Robin. Undefeatable!
# 77                                                                                                                                                                                                       RT @BrickkenSTO: 🔥🚀Our Private Sale of our #cryptocurrency $BKN has begun! 🚀🔥\n\n🤯 We are looking forward on creating a full decentralized ec…
# 452                                                                                                                                                                                                                                     I'm trading in @Fetch_ai \nAnd gaing a great profit from $FET \n#crypto #fetch #altcoin https://t.co/MQLOH8Qb3y
# 129                                                                                                                                                                                                                                RT @carolintaling: #Cardano Alonzo testnet will go live today, mainnet coming September 12. Such an exciting times 💥
# 34                                                                                                                                                                                                         RT @TheCountryBoys: @VikingoBitcoin1 @Rothmus @fartface2000 I literally have real data 36% of small-medium businesses in the US accept Bitc…
# 24                                                                                                                                                                                                                                    Altcoin Roundup: High Ethereum fees kick-start a liquidity migration to layer-1 platforms https://t.co/x1SEhN6mXv
# 14                                                                                                                                                                                                           RT @MOONSHOTJOSH: $FET @Fetch_ai is now in the top 15 favorite coins on @coinbase! Soon it will be in the top 5 ✍️ https://t.co/ksxZet9rBJ
# 174                                                                                                                                                                                                                                                         RT @DaveLikesCrypto: How I'm feeling about #cardano smart contracts https://t.co/FYyrBVCnwc
# 413                                                                                                                                                                                                        RT @InputOutputHK: So there we have it. Since c. 20:20 UTC today, the #Cardano Testnet now officially supports #Plutus #smartcontracts. Fin…
# 227                                                                                                                                                                                                        RT @CedYoungelman: If you came across a house that was worth a million dollars but it was selling for between $40,000 and $60,000, would yo…
# 294                                                                                                                                                                                                      RT @binance: Crypto Summer Is Here! Stay Fit with https://t.co/LQPcQ6GVnh $FET @Fetch_ai and Dive into the $200,000 Prize Pool!\n\n➡️ https:/…
# 514                                                      Amazon Posts Crypto Job Listing, Bitcoin Skyrockets\nBitcoin hit a six-week high of nearly $59,043 and Ethereum hit $3,363. Found this page useful? Please donate to our Bitcoin Wallet: 1FmA87x9GrwnYCVvBUEh1yfnPScivdJn4a #bitcoinblockchain https://t.co/ZqXeqfNuVT https://t.co/US904HJUTm
# 710                                                                                                                                                                                                  RT @KianuPicanto: I sent 1 $FET from Binance to Cosmostation with a 0.5 FET fee - arrived in under 2 minutes\n \n\n Also sent 28 $FET and the fee…
# 47                                                                                                                                                                                                                                             RT @kokid951: Enjoy the Process. #DogeCoin 🐕🪙\n\n🟩🟩🟨🟨🟨🟨🟨🟨🟨🟨\n       🚀                                 $1
# 125                                                                                                                                                                                                        RT @InCommPayments: We're expanding our #payments solutions through our partnership with @FlexaHQ, offering our global #retail partners a s…
# 177                                                                                                                                                                                                                                        Do you now believe? #hex #dogecoin #bitcoin #ethereum #pulsechain #Polkadot #Cardano https://t.co/4wJuxk5awv
# 95                                                                                                                                                                                                                                                       #Bitcoin, #Ethereum  is down by by 4%. we might not see this dip again https://t.co/T9uXd3HJsl
# 224                                                                                                                                                                                                                                                                                              @Fetch_ai $fet is making it's way. Just hang in there.
# 571                                                                                                                                                                                               #Bitcoin IF it breaks below $35K decisively, it ain’t gonna be looking good; \n \n\n Gonna be bloody if &amp; only if the above condition holds true!
# 367                                                                                                                                                                                                                                                                                                                    @coinbase Shiba coinbase l happy
# 611                                                                                                                                                                                                      RT @Cryptoin51: Be ready for this #Cardano move!!! \nIf #ADA breaks 2,86 and confirms the breakout + volume, we are going to a new ATH! \nTar…
# 46                                                                                                                                                                                                         RT @ClayHinFacts: @CGasparino @SEC_Enforcement @Ripple @CFTC After leaving, he took a cushy job with a hedge fund that made a $1B bet on th…
# 488                                                                                                                                                                                                        RT @ShibaAustralia: Time to keep track of the Leash Lovers here - Based on activity, engagement, and following, the top 1-month $LEASH infl…
# 295                                                                                                                                                                                                       RT @NickMagno2: #Holochain process Billions of TPS and still as quick as the flash.\n\n#BTC #Ada #shiba #Eth #doge #MATIC #XRPCommunity #xlm…
# 417                                                                                                                                                                                                      RT @cloudatio: BREAKING: EVERGRANDE CONVERTED ALL REMAINING ASSETS AND EQUITIES INTO BITCOIN TO AVOID CONFISCATION DUE TO BANKRUPTCY.\n SOURC…
# 314                                                                                                                                                                            @papousse47 @MOONSHOTJOSH @Fetch_ai Yep! there is not an area of art or industry where FET Co  Learn can't be used to improve it. This revolution will not be televised!
# 190                                                                                                                                                                                                         RT @MOONSHOTJOSH: Poll time. Who do you think are the major corporations that have been buying up the $FET @Fetch_ai top 100 list? Over 80…
# 263                                                                                                                                                                                                                                                                                            Shiba inu such a shit coin idk why ppl taking it serious
# 51                                                                                                                                                                                                         RT @CGasparino: For the record I wasn’t trying to take sides other than point out what is arguably an inconsistency in ⁦@SECGov⁩ #crypto en…
# 331                                                                                                                                                              China's Evergrande Default Risk Could Have Ripple Effect in Crypto Markets | https://t.co/LZApEXT8Ih Crypto News LIVE Media https://t.co/PbIHq6y0qb - #bitcoin #crypto #cryptocurrency
# 365                                                                                                                                                        Anyone else feeling #Ramen weather? Get yourself a hot bowl at Shiba Ramen at Public Market. So much goodness in every drop!\n\n#ShibaRamen #RamenWeather #RamenTime https://t.co/m1GAjWT8zO
# 170                                                                                                                                                                                                        RT @CryptoBokiWop: #SHIBARMY YOU CAN NOW TRADE $SHIB ON @COINBASE BUT DONT STOP #USESHIBASWAP @SHYTOSHIKUSAMA @SHIBAINUART @SHIBINFORMER $B…
# 139                                                                                                                                                                                           @oddgems @BloXmove @energywebx @Fetch_ai @oceanprotocol Take a look at $YAY protocol , haven't been bullish about a project like these for a long time !!
# 35                                                                                                                                                                                                                                                                                                                                    @Cardano_420 🔥🔥🔥🔥
# 396                                                                                                                                                                                           @blockchainedbb I've made a lot of money on Shiba, but I cashed out at waaaay higher prices than this. Shiba will never again reach the levels I sold at.
# 414                                                                                                                                                                                     Can Ethereum Hit $20k This Cycle? Is #ETH Following #Bitcoins Price Traj... https://t.co/jXSt67g6FZ via @YouTube #Altcoins #cryptocurrency #CryptoNews #Bitcoin
# 607                                                       @Jairzin74324251 @SickoCoin @oyinbo @greeniydbandit @CosmostationVD @IBCwallet @Fetch_ai somebody said it and it worked.. i just went to the web version of cosmostation and imported my account there.. everything seems to be functioning.. just claimed some rewards to test and it worked
# 568                                                            ⏳ Atualização a cada hora\n\n     🪙 1 BTC - R$ 236884,20\n     💎 1 ETC - R$ 17072,74\n     ❈  1 ADA - R$ 12,41\n     ✖️ 1 XRP - R$ 5,58\n     🐶 1 DOGE - R$ 1,25\n\n     💵 1 US$ - R$ 5,24\n     ✈️ 1 US$ Tur - R$ 5,47\n\n     #bitcoin #ethereum #cardano #ripplexrp #dogecoin #dollar
# 212                                               @elonmusk @Shibtoken Shiba Inu is the biggest theft in history Remember my words Token Scam \n@Shibtoken @ShibaSwap @Shilbtoken @elonmusk @VitalikButerin @H_O_L_O_ @btc\n#shiba #ShibaCoin \nDog Dogecoin and Sheba to death money laundering ended\ngo with me to #xecbusd #xec #xeccoin \n#tweeted
# 274                                                                                                                                                                                                                                                                                                                     @Shibtoken 🔥🔥🔥🔥burn some $Shiba
# 551                                                                                                   Trending Crypto Alert!🚨 #Ethereum $ETH is trading at USD 3211.15. Price Change: $ -240.6410222244 || -6.9715 %. Days HIGH: $3515.96 || Days LOW: $3171.18. Volume: $24060351103 Market Cap: $377031347713 MARKET RANK: 2. #cryptocurrency #crypto
# 246                                                                                                                                                                                                  RT @nierop_pieter: WOW !\n\nOn average 9,600 new wallets per day (290,000 monthly)\n\nImagine December there were only 150,000 in total.\n\nAug 2…
# 42                                                                                            @BTCMarkets Ripple is NOT also known as XRP, ripple is a company that has products on the XRPL, XRP is the digital asset for XRPL. Do better. Also, disappointing you’re not distributing Songbird, your support team don’t even know about it- do bette.
# 442                                                                                                                                                                                                   RT @PaulieVal: $FET @Fetch_AI\n#Fetch #FetchAI\n#FetchAgents #DefiAgents #FetARMY\n#AutonomousEconomicAgent\n#Autonomous\n#AI #ArtificialIntelli…
# 125                                                                                                                                                                                                  RT @nierop_pieter: WOW !\n\nOn average 9,600 new wallets per day (290,000 monthly)\n\nImagine December there were only 150,000 in total.\n\nAug 2…
# 126                                                                                                                                                                                                    RT @INotoriousxrp: @CGasparino The Media will hear all of us soon.\nWe need CLARIFICATION not Enforcement!\n#RelistXRP\nRt...123 \n#XRPARMY #cr…
# 645                                                                                                                                                                                                                            RT @nayibbukele: We just bought the dip.\n \n\n 150 new coins!\n \n\n El Salvador now holds 700 coins.\n \n\n #Bitcoin🇸🇻
# 460                                                                                                                                                                                                     RT @spawn_crypto: Fun fact:\n#Nexus already did a 1000x from 0,01$ to 10$ between Jun 2016 to Jan 2018\n\nA 1000x from now will be 650$ per Ne…
# 119                                                                                                                                                                                                                                                                                                                          Bitcoin is so lowwww. #BTC
# 484                                                                                                                                                                                                        RT @TheADAApe: "We're planning on offering significantly nicer staking rewards for the $AGIX on #cardano token than we have been for the #e…
# 339                                                                                                                              #BTC #BTCUSD #Crypto \n bitcoin bear possibility - ( 4 year convex arc is still in action so i am still bullish on bitcoin but we cant rule out the possibilty of going into a bear market )\n https://t.co/qbJoxIUzdM
# 294                                                                                                                                                                                                        RT @eBargainsToday: US Treasury Dept sanctions crypto OTC broker Suex for alleged role in facilitating transactions for ransomware attacks:…
# 402                                                                  With @Shibtoken becoming tradebale on coinbase, don’t forget to transfer funds to a wallet to dig, bury, and woof your shiba!! Long hodlers might as well make passive income with rewards as well as fueling the ecosystem using the platform!! It’s super easy to navigate too!!
# 211                                                                                                                                                                                                         @NVISIONCREATIO1 @CryptoWizardd @Astrones2 @jonathanbosh @FOImagery @Comolokoz1 @cryptocevo @mewnsewn @Fetch_ai @Crypto_Yisus I love $FET 😍
# 767                                                                                                                                                                                                                                                                       RT @greek_prick: China: We ban #Bitcoin\n Also China: https://t.co/ojBa6s8HBB
# 54                                                                                                                                                                                                         RT @CEOAdam: I sincerely want to hear your opinion, via this Twitter Poll. By year-end 2021, AMC will take Bitcoin, Etherum, Litecoin and B…
# 392                                                                                                                                                                                                                                                                                                         If Shiba get to 0.2€ I will retired😭😭#Shiba
# 236                                                                                                                                                                                                      RT @GD10V: We are always on the lookout for the next great blockchain game, especially on #Solana ⚡️\n\nIn our eyes @CryowarDevs is it. So he…
# 365                                                                                                                                                                                                    RT @crypto_jedi_1: $PROGE $ROGE can’t believe people are sleeping on these\n\n#CMC listing for Proge within the next 24 hrs 🔥🔥🔥🔥\n\n#Ethereum $…
# 1                                                                                                                                                                                                                                                                                               Heeeeey, I know you got that LUST\n In Bitcoin we TRUST
# 463                                                                                                                                                                             Altcoin Roundup: High Ethereum fees kick-start a liquidity migration to layer-1 platforms https://t.co/HPAHX7kjq1 #AltcoinWatch #Liquidity #DeFi #NFT #Cryptocurrencies
# 845                                                                                                                                                                                                       RT @anumnasar3: @binance @Fetch_ai 🔮 Utopia - Built today, for a better tomorrow!\n 📱 Multiple Usecases including DEX, Crowdfunding, Charity…
# 594                                                                                                                                                                                                        RT @theCOTIinvestor: Hi @jack, nice move with #Bitcoin on #Twitter. I know you get lots of messages and tags, but if you look for a payment…
# 762                                                                                                                                                                                                                                                                                                  You know who else wants to ban Bitcoin? BILL GATES
# 171                                                                                                                                                                                                                  @GiveAwayHost gonna be a hug !! when i look this i believe so many people are putting their trust in this #MadTrooper #NFT #Solana
# 185                                                                                                                                                                                                                                                     @judge_joe_brown thank you brodie!! just bought my first bitcoin miner…. it cost like 7 grand 😅
# 503                                                                                                   @tmacsalt @BitcoinQ_A You mean M.A.P sympathizer Vitalik, and his Inferium mETH lab??\n\nDOT, Solana, ETC, TRON, even Cardano Vaporware, all catching up to the Buterin Buffoon Buffet!!\n\nSoon, even Lightning defi will surpass Fail-therium!!
# 155                                                                                                                                                                                                          RT @SalsaTekila: Dear noobs, \n  Bitcoin is NOT naturally going down. It is being pushed down via whales placing spoofy sell orders on ex…
# 304                                                                                                                                                                                                                                                                                              @APompliano @brian_armstrong Why does he hate bitcoin?
# 262                                                                                                                                                                                                                                                                             A @Fetch_ai wallet where we can stake our coins would be the shit. $FET
# 623                                                                                                                                                                                                        RT @stockjupiter_: if you aren't talking about $AGIX, you're in for a hell of a surprise - SingularityNET will be integrating their AI into…
# 654                                                                                                                              @landana1 @Fetch_ai I have suffered from this same issue for 2months .. As soon as I wrote to Metamask support using this link below everything was settled, don't forget to thank me later.\n https://t.co/7GIJLjzngm
# 452                                                                                                                                                                                                                                                            RT @Swag_Stakepool: 800K Delegated wallets! 🔥🔥🔥\n\n#Cardano $ADA https://t.co/L149zMA65J
# 184                     Bitcoin mining ⛏ omits massive amounts of #Carbon into the atmosphere like #CrudeOil and #Methane \n \n\n Did crypto mining shut down #Texas Energy grid or #hackers ? \n \n\n Satoshi Nakamoto is #Fake Maybe CIA\n \n\n #bitcoins #cryptocurrency #Biden #germany #UAE #USA $QQQ $DIA $SPY $VIX $SQQQ https://t.co/ZMk9PdpFGc
# 29                                                                                                                                                                                                                                 RT @shibsta1: They called us mad men but here we are.\nSheeeesh!\n2 da moon baby!\n#shibarmy #shib #shiba @Shibtoken
# 164                                                                                                                                                                                                                                                                     RT @mikealfred: Bitcoin is Aspen\nEthereum is San Francisco\nCardano is Detroit
# 424                                                                                                                                                                                                      RT @ilnoir1: Hey #SHIBARMY !!\nLet’s kill the fucking zeros of #SHIB !!! \n#shibtothemoon #shibainu #ShibaSwap  #ShibaArmy #shibarium #shib #…
# 80                                                                                                                                                                                                       RT @100trillionUSD: Gary Gensler (SEC):\n - is going after the "5000 or 6000 PROJECTS that are raising money from the public [..] anticipatin…
# 829                                                                                                                                         @binance @Fetch_ai Have you guys heard about altura it is a smart nft platform which is also bringing its play to earn soon .It has also partnered with chainlink and cryptoblades, potentially a 100x coin
# 688                                                                                                                                                                                                        RT @steve_hanke: The price of #Bitcoin tanked over 9% to $41,083 following China’s crypto ban announcement. Why should decisions made by th…
# 52                                                                                                                                                                                                                                                                                                             @TheMoonCarl Nah man I'm bull on #solana
# 328                                                                                                                                                           OG Edition: Bill Tai on Bitcoin’s Early Days and the Social Potential of NFTs | https://t.co/LZApEXT8Ih Crypto News LIVE Media https://t.co/Y9mr3jYCLC - #bitcoin #crypto #cryptocurrency
# 593                                                                                                                                                                                                         RT @ErydsLo: @Bent35279044 I'm liking my Algorand, my https://t.co/K8Nod5KWFd and my Clover. I would love XRP, but again...it was too earl…
# 410                                                                                                                                                                                                                   RT @markets: Bitcoin fell for a third day, dropping briefly below $40,000 for the first time since August https://t.co/Tr0W33d2Y9
# 134                                                                                                                                                                                                                                                    @krakenfx $FET\n\n@krakenfx Could you add Fetch Ai to your platform. It'd be greatly appreciated
# 610                                                                                                                                                                                                                                                                            RT @kimihonakamura1: フランスのテレビで、生態学的なBitcoinとして説明されたようぜよ🔥\n＃Cardano(＃ADA）
# 197                                                                                                                                                                                                             RT @michael_saylor: In the long run, it won’t matter if the price of #bitcoin was .01 or .03 or .05 million dollars when you bought it.
# 81                                                                                             There are 2 facts that the Amazing Alligator team believes in.\nThe fact that Solana is going to moon. It is on of the most innovative blockchains on cryptocurrency and the fees that are tens of times cheaper than Ethereum truly make it elite.\n1/2
# 345                                                                                                                                                                                                                                                                                            Love #Solana but get it together https://t.co/xiPXlFmt6j
# ...
# 161                                                                                                                                                                                            RT @sonicGsh: #Bitcoin $BTC\n \n\n Read\n \n\n Only way for this pattern to PARTIALLY fail is by having a V pattern correction to the up side and break…
# 304                                                                                                                                                                                                                                                                                                                       @Fetch_ai  $FET is THE future
# 89                                                                                                                                                                                                  RT @XRPNews_: Ripple #XRP News - Ripple v SEC Lawsuit FRONT &amp; CENTER ON FOX BUSSINESS + Massive New RIPPLE PARTNER!\n\nVideo Below\nhttps://t.…
# 581                                                                                                                                                                                                                                               @landana1 @Fetch_ai Do you need any help or support with your metamask wallet https://t.co/sc9NcNwgvQ
# 340                                                                                                                                                                                                         RT @mikealfred: So glad that I'm free to tell the truth. Cardano is one of the longest running scams in crypto. I don't care that you know…
# 197                                                                                                                                                                                                     I have to share with you, how I look on $FET chart. IMO if we hold the green line, 3k sat is the next target. @Fetch_ai https://t.co/8xQMFufgN1
# 145                                                                                                                                                                                                                                                  @PubityOnInsta Just received 510 million SHIB. Thank you @SHIBAINUBONUS We are with you SHIBA COIN
# 206                                                                                                                                                                                                          RT @mikealfred: #Bitcoin is the true meta verse asset. NOT Cardano. NOT Ripple. NOT Tron. NOT Doge. NOT any other crypto. It is so ahead.…
# 735                                                                                                                                                                                                                                                                                              RT @scottmelker: Buying more #Bitcoin here around 42K.
# 760                                                                                                                                                                                                                              RT @BitcoinMagazine: #Bitcoin is up over $40,000 since the first "China ban."\n \n\n Zoom out. https://t.co/GLODqOKetL
# 53                                                                                                                                                                                                     RT @Mk2Trading: #Ethereum \n\nAs ETH is selling off, I have marked some pivots where it might bounce. \n\nFirst pivot at 3145 (the current sell…
# 403                                                                                                                                                                                                        RT @MOONSHOTJOSH: Some still don’t understand how big $FET @Fetch_ai is going to be 😅\n#FetchAI #Bosch #TheFutureIsNow $SOL $BNB $ADA $USDT…
#
#      actual  predicted
# 722       0          1
# 81        0          1
# 65        1          0
# 355       1          0
# 261       0          1
# 44       -1          0
# 400       0          1
# 167       0          1
# 80        1          0
# 220       0         -1
# 378       1          0
# 433       1          0
# 709       1          0
# 197       1          0
# 475       0         -1
# 701       1         -1
# 485      -1          0
# 143      -1          0
# 119      -1          1
# 216       1          0
# 72        1          0
# 397       1          0
# 140       1          0
# 323       1          0
# 53        0          1
# 258      -1          0
# 389       0          1
# 534       0          1
# 383       1          0
# 751       1          0
# 5         1          0
# 695       0         -1
# 255       0         -1
# 101       0          1
# 401       0          1
# 149       0         -1
# 309       0          1
# 302       0         -1
# 711      -1          1
# 183       1          0
# 98        1          0
# 130       1          0
# 377      -1          0
# 500      -1          0
# 58       -1          0
# 521       0         -1
# 74        0          1
# 473       1          0
# 34        0          1
# 77        0          1
# 452       1          0
# 129       0          1
# 34        1          0
# 24       -1          0
# 14        1          0
# 174       0          1
# 413       0          1
# 227       1          0
# 294       0          1
# 514       1          0
# 710       0          1
# 47        0          1
# 125       0          1
# 177       0          1
# 95       -1          0
# 224       1          0
# 571      -1          0
# 367       1          0
# 611       1          0
# 46       -1          0
# 488       0         -1
# 295       0          1
# 417       0          1
# 314       1          0
# 190       0          1
# 263      -1          1
# 51       -1          0
# 331      -1          0
# 365       0          1
# 170       1          0
# 139       0          1
# 35        0          1
# 396      -1          1
# 414       0         -1
# 607       0         -1
# 568       0          1
# 212      -1          0
# 274       0          1
# 551       0          1
# 246       1          0
# 42        0          1
# 442       0          1
# 125       1          0
# 126      -1          1
# 645       1          0
# 460       1          0
# 119      -1          0
# 484       1          0
# 339      -1          1
# 294      -1          0
# 402       1          0
# 211       1          0
# 767       0         -1
# 54        0          1
# 392       1          0
# 236       1          0
# 365       0          1
# 1         1          0
# 463      -1          0
# 845       0          1
# 594       0          1
# 762      -1          0
# 171       0          1
# 185       1          0
# 503       0          1
# 155      -1          1
# 304      -1          0
# 262       1          0
# 623       1          0
# 654       1         -1
# 452       1          0
# 184      -1          0
# 29        1          0
# 164      -1          0
# 424       1          0
# 80       -1          0
# 829       0          1
# 688      -1          0
# 52        1          0
# 328       0         -1
# 593       1          0
# 410      -1          0
# 134       1          0
# 610       0          1
# 197       1          0
# 81        1         -1
# 345      -1          0
# 31        0          1
# 199       1          0
# 170       1          0
# 412      -1          0
# 914       0          1
# 98       -1          0
# 560       0          1
# 331       1          0
# 423       1         -1
# 357       0          1
# 226       1          0
# 469       0         -1
# 193       0          1
# 209       0          1
# 361      -1          1
# 96        1          0
# 651       1          0
# 185       0          1
# 250      -1          0
# 60        1         -1
# 92        1          0
# 185       0         -1
# 402       1          0
# 708      -1          0
# 284      -1          1
# 279       1          0
# 109       1          0
# 141       0          1
# 185       1          0
# 655      -1          0
# 565      -1          0
# 375      -1          0
# 696       0          1
# 783       0          1
# 449      -1          1
# 292       1          0
# 23        0          1
# 233       1          0
# 756       0          1
# 750       1          0
# 248       0          1
# 426       0          1
# 129       1          0
# 601       0          1
# 46       -1          0
# 3         0          1
# 383       1          0
# 712      -1          1
# 97        0          1
# 166       1         -1
# 434      -1          0
# 65        0          1
# 62        1          0
# 193      -1          0
# 163       0          1
# 665       0          1
# 740       1          0
# 137       0          1
# 395      -1          0
# 668      -1          0
# 347      -1          0
# 333      -1          0
# 132       1          0
# 188       0          1
# 536       1          0
# 208       1          0
# 319       1          0
# 135       0          1
# 65        0         -1
# 371       0         -1
# 109       1          0
# 97        0          1
# 214      -1          0
# 123      -1          0
# 33       -1          0
# 117       1          0
# 644      -1          0
# 139       1          0
# 1         1          0
# 659      -1          1
# 134      -1          0
# 165       1          0
# 62        1          0
# 99        0         -1
# 129       1          0
# 654      -1          0
# 323      -1          0
# 172      -1          0
# 507      -1          0
# 13        0          1
# 196       1          0
# 535       1         -1
# 276       0          1
# 93        0          1
# 546       0         -1
# 256       0          1
# 11        0          1
# 308       0          1
# 461      -1          0
# 82        0          1
# 383      -1          0
# 234       1          0
# 774      -1          0
# 60        0          1
# 116       0         -1
# 120       0          1
# 19        0          1
# 548       0          1
# 76        0          1
# 163      -1          0
# 17        0          1
# 341       1          0
# 663       0          1
# 350       0          1
# 617       1          0
# 254       1          0
# 297      -1          0
# 638       0          1
# 340      -1          0
# 527       0          1
# 431       0          1
# 51        0          1
# 531       0          1
# 312       0          1
# 79        1          0
# 90       -1          1
# 841       1          0
# 592       1          0
# 476      -1          0
# 349       1          0
# 610      -1          0
# 639      -1          0
# 72        1          0
# 784       0         -1
# 705       0         -1
# 464       1          0
# 48        0          1
# 32       -1          1
# 84       -1          0
# 512       1          0
# 142       1          0
# 824      -1          1
# 641       0         -1
# 24        0          1
# 244       0          1
# 141       1          0
# 862       1          0
# 56        1          0
# 221       0          1
# 340       0         -1
# 108       1          0
# 31        0          1
# 574       1          0
# 808      -1          0
# 557       0          1
# 309       1          0
# 676       1          0
# 349       1          0
# 27        1          0
# 225       0          1
# 755       0         -1
# 164       0          1
# 431       1          0
# 693       0          1
# 462      -1          0
# 253       1          0
# 38        1          0
# 176       0         -1
# 88        0         -1
# 523       1         -1
# 199       0          1
# 285       0          1
# 99        1          0
# 412       0          1
# 583      -1          0
# 471       0          1
# 327       1          0
# 809      -1          0
# 871       0          1
# 136       0          1
# 540       0          1
# 313      -1          1
# 228      -1          0
# 171       0          1
# 158       1          0
# 96        1          0
# 428       0          1
# 817      -1          0
# 39        1          0
# 383       1          0
# 443      -1          0
# 720       0          1
# 682       1          0
# 468       1          0
# 110       1          0
# 163       1          0
# 92        0          1
# 160       1          0
# 144       0          1
# 209       0          1
# 287       1          0
# 189       0          1
# 513       1          0
# 553       1          0
# 235       0          1
# 653       1         -1
# 128       1          0
# 127       1          0
# 362      -1          0
# 381      -1          0
# 323       1          0
# 111       1          0
# 294       1          0
# 314       0          1
# 356      -1          0
# 34        0         -1
# 482       1          0
# 650       1          0
# 284       0          1
# 542       0          1
# 6         1          0
# 436      -1          0
# 91        1          0
# 569       1          0
# 801       1          0
# 44        1          0
# 400       1          0
# 323       1          0
# 510       1          0
# 353       0         -1
# 64       -1          0
# 515       1          0
# 151       0         -1
# 743       1          0
# 389       1          0
# 250       0          1
# 18        1          0
# 166       0          1
# 28       -1          0
# 396       0          1
# 248      -1          0
# 328      -1          0
# 611       0          1
# 289      -1          1
# 886       1          0
# 35       -1          0
# 514       1         -1
# 558       0         -1
# 249      -1          0
# 80        0          1
# 198       0          1
# 292       0          1
# 798       1          0
# 897       1          0
# 390       1          0
# 305      -1          0
# 293       0          1
# 317       0          1
# 42        1          0
# 174       0          1
# 301      -1          0
# 250       0          1
# 620       1          0
# 237      -1          0
# 740       0          1
# 377       1          0
# 408       1          0
# 131      -1          0
# 301       0          1
# 86        1          0
# 132      -1          0
# 650       0          1
# 237       1          0
# 181       1          0
# 373       0          1
# 208      -1          0
# 103       1          0
# 224       1          0
# 631       0          1
# 278      -1          0
# 827       0          1
# 474      -1          0
# 35        1          0
# 404       0          1
# 748      -1          0
# 649       1          0
# 147       0         -1
# 0         1          0
# 457       1         -1
# 138       1         -1
# 306       0          1
# 242       1          0
# 612       1          0
# 405      -1          1
# 361      -1          0
# 28        0          1
# 111       1          0
# 167       1          0
# 355       0          1
# 498       0         -1
# 490       0         -1
# 728       1          0
# 538       1          0
# 217       1          0
# 344       0          1
# 203       1          0
# 86        0         -1
# 159       1          0
# 19        1          0
# 61       -1          1
# 788      -1          0
# 41        1          0
# 422       1          0
# 25        1          0
# 115      -1          1
# 476       0          1
# 249       0          1
# 748       1          0
# 235       1         -1
# 161       0          1
# 304       1          0
# 89       -1          0
# 581      -1          0
# 340      -1          0
# 197       0          1
# 145       1          0
# 206      -1          1
# 735       1          0
# 760       1         -1
# 53        0         -1
# 403       1          0

# %% [markdown]
# # New Examples

# %%
predict_text("$ETH $DOGE $SHIB To The Moon")
# Out:
# 'Neutral'

# %%
predict_text("Somewhere In Florida #Doge #Dogecoin #Crypto")
# Out:
# 'Neutral'
