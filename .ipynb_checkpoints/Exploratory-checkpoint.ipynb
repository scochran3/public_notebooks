# %%
import pandas as pd
from glob import glob
import seaborn as sns
from bokeh.io import curdoc
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import ColumnDataSource, RangeTool, NumeralTickFormatter, Range1d, LabelSet, HoverTool
from bokeh.themes import Theme
from bokeh.embed import components
from bokeh.transform import cumsum
from bokeh.layouts import layout
from bokeh.models.widgets import Tabs, Panel
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-55-8ec9067d508e> in <module>
#      10 from bokeh.layouts import layout
#      11 from bokeh.models.widgets import Tabs, Panel
# ---> 12 from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
# Styles for Bokeh Plots
THEME = Theme(json={
    'attrs': {
        'Figure': {
            'sizing_mode': 'stretch_width',
            'plot_height': 500,
            'background_fill_color': '#FFFFFF',
            'border_fill_color': '#FFFFFF',
            'outline_line_color': '#FFFFFF',
        },
        'Axis': {
            'major_label_text_font_size': '12pt',
            'minor_tick_line_color': "white",
            'axis_label_text_font_size': '14pt',
            'axis_label_text_font_style': 'bold',
            'axis_label_text_font_style': 'italic'
        },
        'Grid': {
            'grid_line_color': None
        },
        'Line': {
            'line_color': '#000000',
            'line_width': 2,
        },
        'Bar': {
            'fill_color': '#000000'
        },
        'Title': {
            'text_color': "#000000",
            'text_font_size': '16pt',
            'text_font_style': 'bold'
        }
    }
})
doc = curdoc()
doc.theme = THEME

# Colors for charts
PRIMARY_COLOR = '#000000'
SECONDARY_COLOR = '#000000'
GRAY = '#A9A9A9'
COLORS = ['#4101f5', '#21e68c', '#b22c99',
          '#8c1932', '#509bf5', '#fae62c', '#f59b22', '#f5729f', '#ff4935']
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Combine Datasets

# %%
df = pd.DataFrame()
for csv in glob('data/*.csv'):
    this_df = pd.read_csv(csv)
    df = df.append(this_df)

df.set_index('date', inplace=True)
df.to_csv('combined_data.csv')

# %%
combined_df = pd.read_csv('combined_data.csv')
combined_df
# Out:
#            date         published_at         source_id       source_name  \
# 0    2021-08-02  2021-08-02T20:10:00           reuters           Reuters
# 1    2021-08-02  2021-08-02T15:56:45         the-verge         The Verge
# 2    2021-08-02  2021-08-02T10:53:05         vice-news         Vice News
# 3    2021-08-02  2021-08-02T10:53:05         vice-news         Vice News
# 4    2021-08-02  2021-08-02T04:16:41               NaN         HYPEBEAST
# ..          ...                  ...               ...               ...
# 796  2021-08-08  2021-08-08T13:56:47  associated-press  Associated Press
# 797  2021-08-08  2021-08-08T22:00:18               NaN  Survivalblog.com
# 798  2021-08-08  2021-08-08T22:00:38               NaN        Bitcoinist
# 799  2021-08-08  2021-08-08T04:16:10  associated-press  Associated Press
# 800  2021-08-08  2021-08-08T09:34:09               NaN         NDTV News
#
#                                         author  \
# 0                     Gertrude Chavez-dreyfuss
# 1                                 Makena Kelly
# 2             Rimal Farrukh, Sahar Habib Ghazi
# 3             Rimal Farrukh, Sahar Habib Ghazi
# 4    info@hypebeast.com (HYPEBEAST), HYPEBEAST
# ..                                         ...
# 796                               Lisa Mascaro
# 797                        James Wesley Rawles
# 798                              Jacob Holiday
# 799                               Lisa Mascaro
# 800                                        NaN
#
#                                                content  \
# 0    A representation of the virtual cryptocurrency...
# 1    It includes billions for broadband expansion\r...
# 2    After a fight with his best friend, an embitte...
# 3    After a fight with his best friend, an embitte...
# 4    CryptoPunks have seen a resurgence once again ...
# ..                                                 ...
# 796  WASHINGTON (AP) Senators will resume a weekend...
# 797  Here are the latest news items and commentary ...
# 798  Brian Brooks, CEO resigned as CEO of Binance.U...
# 799  WASHINGTON (AP) Senators will resume a weekend...
# 800  Originally, stablecoins were primarily used to...
#
#                                                  title  \
# 0    Crypto sector sees outflows for 4th week in a ...
# 1    Senate negotiators release bipartisan infrastr...
# 2    The Viral Friendship Break Up Meme Just Sold F...
# 3    The Viral Friendship Break Up Meme Just Sold F...
# 4    CryptoPunk Prices See 53% Increase After Ether...
# ..                                                 ...
# 796  Senate slog to pass infrastructure bill goes o...
# 797                 Economics & Investing For Preppers
# 798  Binance US CEO Brian Brooks Resigns After 4 Mo...
# 799  Senate slog to pass infrastructure bill goes o...
# 800  What Are Stablecoins? A Blockchain Expert Expl...
#
#                                                    url  \
# 0    https://www.reuters.com/business/finance/crypt...
# 1    https://www.theverge.com/2021/8/2/22605917/sen...
# 2    https://www.vice.com/en/article/m7ek5v/viral-f...
# 3    https://www.vice.com/en/article/m7ek5v/viral-f...
# 4    https://hypebeast.com/2021/8/cryptopunk-price-...
# ..                                                 ...
# 796  https://apnews.com/article/congress-senate-inf...
# 797  https://survivalblog.com/2021/08/09/economics-...
# 798  https://bitcoinist.com/binance-us-ceo-brian-br...
# 799  https://apnews.com/article/joe-biden-business-...
# 800  https://www.ndtv.com/business/what-are-stablec...
#
#                                              url_image
# 0    https://www.reuters.com/resizer/lmbIm3yyzD-3za...
# 1    https://cdn.vox-cdn.com/thumbor/-Ptu6iB68qfRKY...
# 2    https://video-images.vice.com/articles/6107c17...
# 3    https://video-images.vice.com/articles/6107c17...
# 4    https://image-cdn.hypb.st/https%3A%2F%2Fhypebe...
# ..                                                 ...
# 796  https://storage.googleapis.com/afs-prod/media/...
# 797  https://survivalblog.com/wp-content/uploads/20...
# 798  https://bitcoinist.com/wp-content/uploads/2021...
# 799  https://storage.googleapis.com/afs-prod/media/...
# 800  https://c.ndtvimg.com/2021-07/2uash6u8_bitcoin...
#
# [801 rows x 9 columns]

# %% [markdown]
# # Posts by Publication

# %%
by_publication = combined_df.groupby('source_name')[['url']].nunique().reset_index().sort_values(by='url').tail(20)
by_publication.columns = ['source', 'articles']

# %%
source = ColumnDataSource(by_publication)
p = figure(y_range = by_publication['source'], toolbar_location=None)
p.hbar(y='source', right='articles', source=source, color='#000000', height=.5)
p.x_range = Range1d(0, by_publication['articles'].max()*1.05)
show(p)
# Out:
#   <div class="bk-root" id="b353885a-bd96-47ee-bf76-c41fdc8f993a" data-root-id="1586"></div>

# %% [markdown]
# # By Author

# %%
by_author = combined_df.groupby('author')[['url']].nunique().reset_index().sort_values(by='url').tail(20)
by_author.columns = ['author', 'articles']
by_author['truncated'] = by_author['author'].apply(lambda x: x[0:45])

# %%
source = ColumnDataSource(by_author)
p = figure(y_range = by_author['truncated'], toolbar_location=None)
p.hbar(y='truncated', right='articles', source=source, color='#000000', height=.5)
p.x_range = Range1d(0, by_author['articles'].max()*1.05)
show(p)
# Out:
#   <div class="bk-root" id="c0f22482-d04d-4d8b-b052-3f4bdd6c7ac5" data-root-id="1883"></div>

# %% [markdown]
# # Word Counts

# %%
combined_df.head()
# Out:
#          date         published_at  source_id source_name  \
# 0  2021-08-02  2021-08-02T20:10:00    reuters     Reuters
# 1  2021-08-02  2021-08-02T15:56:45  the-verge   The Verge
# 2  2021-08-02  2021-08-02T10:53:05  vice-news   Vice News
# 3  2021-08-02  2021-08-02T10:53:05  vice-news   Vice News
# 4  2021-08-02  2021-08-02T04:16:41        NaN   HYPEBEAST
#
#                                       author  \
# 0                   Gertrude Chavez-dreyfuss
# 1                               Makena Kelly
# 2           Rimal Farrukh, Sahar Habib Ghazi
# 3           Rimal Farrukh, Sahar Habib Ghazi
# 4  info@hypebeast.com (HYPEBEAST), HYPEBEAST
#
#                                              content  \
# 0  A representation of the virtual cryptocurrency...
# 1  It includes billions for broadband expansion\r...
# 2  After a fight with his best friend, an embitte...
# 3  After a fight with his best friend, an embitte...
# 4  CryptoPunks have seen a resurgence once again ...
#
#                                                title  \
# 0  Crypto sector sees outflows for 4th week in a ...
# 1  Senate negotiators release bipartisan infrastr...
# 2  The Viral Friendship Break Up Meme Just Sold F...
# 3  The Viral Friendship Break Up Meme Just Sold F...
# 4  CryptoPunk Prices See 53% Increase After Ether...
#
#                                                  url  \
# 0  https://www.reuters.com/business/finance/crypt...
# 1  https://www.theverge.com/2021/8/2/22605917/sen...
# 2  https://www.vice.com/en/article/m7ek5v/viral-f...
# 3  https://www.vice.com/en/article/m7ek5v/viral-f...
# 4  https://hypebeast.com/2021/8/cryptopunk-price-...
#
#                                            url_image
# 0  https://www.reuters.com/resizer/lmbIm3yyzD-3za...
# 1  https://cdn.vox-cdn.com/thumbor/-Ptu6iB68qfRKY...
# 2  https://video-images.vice.com/articles/6107c17...
# 3  https://video-images.vice.com/articles/6107c17...
# 4  https://image-cdn.hypb.st/https%3A%2F%2Fhypebe...

# %%
no_nulls = combined_df.dropna(subset=['title', 'content'])
no_nulls['text_concat'] = no_nulls['title'] + ' ' + no_nulls['content']
full_text = ', '.join(no_nulls['text_concat'].tolist())
# Out:
# /Users/shawnc/.pyenv/versions/3.6.9/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
full_text
# Out:
# 'Crypto sector sees outflows for 4th week in a row, CoinShares data shows - Reuters A representation of the virtual cryptocurrency Bitcoin is seen in this picture illustration taken June 14, 2021. REUTERS/Edgar Su/Illustration/FilesNEW YORK, Aug 2 (Reuters) - Cryptocurrency investme… [+2265 chars], Senate negotiators release bipartisan infrastructure bill It includes billions for broadband expansion\r\nOn Sunday, a bipartisan group of senators released their over $1 trillion inf